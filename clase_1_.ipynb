# %%
print("¡Diagnóstico: El ambiente federica está vivo!")
# Out:
# ¡Diagnóstico: El ambiente federica está vivo!

# %% [markdown]
# Lista

# %%
L=[1, 2, 3]

# %%
L
# Out:
# [1, 2, 3]

# %%
M=[1, 3.14, 'Flora']

# %%
M
# Out:
# [1, 3.14, 'Flora']

# %%
len(L)
# Out:
# 3

# %%
L.append('OK')

# %%
L
# Out:
# [1, 2, 3, 'OK']

# %%
L[1]= 'Buon Giorno'

# %%
L
# Out:
# [1, 2, 3, 'OK']

# %%
L
# Out:
# [1, 'Buon Giorno', 3, 'OK']

# %%
L[1:3]
L
# Out:
# [1, 'Buon Giorno', 3, 'OK']

# %%
L
# Out:
# [1, 'Buon Giorno', 3, 'OK']

# %%
L[1:3]=[10, 20]

# %%
L
# Out:
# [1, 10, 20, 'OK']

# %%
x in 123
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 x in 123
#
# NameError: name 'x' is not defined

# %%
x=123
x in L
# Out:
# False
